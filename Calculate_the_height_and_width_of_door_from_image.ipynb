# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasad0505/Calculate-the-height-and-width-of-door-from-image/blob/main/Calculate_the_height_and_width_of_door_from_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# Load image
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/imag2.jpg')

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection using Canny
edges = cv2.Canny(blurred, 50, 150)

# Find contours in the edge-detected image
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Loop through the contours
for cnt in contours:
    # Approximate the contour as a polygon
    approx = cv2.approxPolyDP(cnt, 0.04 * cv2.arcLength(cnt, True), True)

    # Check if the approximated contour has four sides (a rectangle)
    if len(approx) == 4:
        # Get the bounding rectangle
        x, y, w, h = cv2.boundingRect(approx)

        # Calculate the aspect ratio
        #aspect_ratio = float(w )/ h

        # Filter out non-rectangular shapes based on aspect ratio
        #if 0.8 < aspect_ratio < 1.2:
print(f"Width: {w}, Height: {h}")
# Out:
# Width: 116, Height: 327

# %%
img
# Out:
# array([[[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 251, 250],
#         [252, 250, 249],
#         [254, 252, 251],
# ...

# %%
print(f"Width of door: {w}, Height of door: {h}")
# Out:
# Width of door: 116, Height of door: 327
